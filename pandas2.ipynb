# %%
import pandas as pd
df=pd.read_csv("taxonomy.csv.xls")

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df.fillna(0)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency         0                     0
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1=pd.read_csv("titanic_data.csv")
df1
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
g=df1.groupby('Survived')
g

# %%
g.sum()
# Out:
# C:\Users\vbhar\AppData\Local\Temp\ipykernel_4456\1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Unnamed: 0  PassengerId  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0             244863       245412    1390  12985.50    304    181  12142.7199
# 1             151632       151974     667   8219.67    162    159  16551.2294

# %%
g.mean()
# Out:
# C:\Users\vbhar\AppData\Local\Temp\ipykernel_4456\2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#           Unnamed: 0  PassengerId    Pclass        Age     SibSp     Parch  \
# Survived
# 0         446.016393   447.016393  2.531876  30.626179  0.553734  0.329690
# 1         443.368421   444.368421  1.950292  28.343690  0.473684  0.464912
#
#                Fare
# Survived
# 0         22.117887
# 1         48.395408

# %%
g1=df1.groupby('Pclass')

# %%
g1.sum()
# Out:
# C:\Users\vbhar\AppData\Local\Temp\ipykernel_4456\2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Unnamed: 0  PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            99489        99705       136  7111.42     90     77  18177.4125
# 2            81872        82056        87  5168.83     74     70   3801.8417
# 3           215134       215625       119  8924.92    302    193   6714.6951

# %%
g1.mean()[['Age','Fare']]
# Out:
# C:\Users\vbhar\AppData\Local\Temp\ipykernel_4456\3032811128.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()[['Age','Fare']]
#               Age       Fare
# Pclass
# 1       38.233441  84.154687
# 2       29.877630  20.662183
# 3       25.140620  13.675550

# %%
g1.mean()[['Age','Fare']].T
# Out:
# C:\Users\vbhar\AppData\Local\Temp\ipykernel_4456\1123784410.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()[['Age','Fare']].T
# Pclass          1          2         3
# Age     38.233441  29.877630  25.14062
# Fare    84.154687  20.662183  13.67555

# %%
g1.max()[['Age','Fare']]
# Out:
# C:\Users\vbhar\AppData\Local\Temp\ipykernel_4456\1573949889.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()[['Age','Fare']]
#          Age      Fare
# Pclass
# 1       80.0  512.3292
# 2       70.0   73.5000
# 3       74.0   69.5500

# %%
s={'col1':1,'col2':2,'col3':3}
dff=pd.DataFrame({'col1':[1,2,3],'col2':[2,3,4],'col3':[3,4,5]})
dff
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     2     3     4
# 2     3     4     5

# %%
df1
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df1.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2=df1[['Name','Pclass','Survived']][0:5]

# %%
df3=df1[['Name','Pclass','Survived']][5:11]

# %%
pd.concat([df2,df3])
# Out:
#                                                  Name  Pclass  Survived
# 0                             Braund, Mr. Owen Harris       3         0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...       1         1
# 2                              Heikkinen, Miss. Laina       3         1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)       1         1
# 4                            Allen, Mr. William Henry       3         0
# 5                                    Moran, Mr. James       3         0
# 6                             McCarthy, Mr. Timothy J       1         0
# 7                      Palsson, Master. Gosta Leonard       3         0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3         1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)       2         1
# 10                    Sandstrom, Miss. Marguerite Rut       3         1

# %%
pd.concat([df2,df3],axis=1)
# Out:
#                                                  Name  Pclass  Survived  \
# 0                             Braund, Mr. Owen Harris     3.0       0.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...     1.0       1.0
# 2                              Heikkinen, Miss. Laina     3.0       1.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)     1.0       1.0
# 4                            Allen, Mr. William Henry     3.0       0.0
# 5                                                 NaN     NaN       NaN
# 6                                                 NaN     NaN       NaN
# 7                                                 NaN     NaN       NaN
# 8                                                 NaN     NaN       NaN
# 9                                                 NaN     NaN       NaN
# 10                                                NaN     NaN       NaN
#
#                                                  Name  Pclass  Survived
# ...

# %%
#merge() works on column values where as join() works on indexs

# %%
df1['Fare_INR']=df1['Fare'].apply(lambda x:x*82)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4=pd.DataFrame({'col1':[1,2,3,4],'col2':[4,5,6,7],'col3':['sudh','krish','hitesh','navin']},index=['a','b','c','d'])
df4
# Out:
#    col1  col2    col3
# a     1     4    sudh
# b     2     5   krish
# c     3     6  hitesh
# d     4     7   navin

# %%
for col_index,row in df4.iterrows():
    print(col_index,row)
# Out:
# a col1       1
# col2       4
# col3    sudh
# Name: a, dtype: object
# b col1        2
# col2        5
# col3    krish
# Name: b, dtype: object
# c col1         3
# col2         6
# col3    hitesh
# Name: c, dtype: object
# d col1        4
# col2        7
# col3    navin
# Name: d, dtype: object

# %%
for col_name,col in df4.iteritems():
    print(col_name,col)
# Out:
# col1 a    1
# b    2
# c    3
# d    4
# Name: col1, dtype: int64
# col2 a    4
# b    5
# c    6
# d    7
# Name: col2, dtype: int64
# col3 a      sudh
# b     krish
# c    hitesh
# d     navin
# Name: col3, dtype: object
# C:\Users\vbhar\AppData\Local\Temp\ipykernel_4456\2727854621.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name,col in df4.iteritems():

# %%
df4
# Out:
#    col1  col2    col3
# a     1     4    sudh
# b     2     5   krish
# c     3     6  hitesh
# d     4     7   navin

# %%
list(df4['col1'])
# Out:
# [1, 2, 3, 4]

# %%
df4.apply(lambda x:x.sum())
# Out:
# col1                      10
# col2                      22
# col3    sudhkrishhiteshnavin
# dtype: object

# %%
df4['col1']=df4['col1'].apply(lambda x:x*2)
df4
# Out:
#    col1  col2    col3
# a     2     4    sudh
# b     4     5   krish
# c     6     6  hitesh
# d     8     7   navin

# %%
df5=df4[['col1','col2']]
df5.applymap(lambda x:x**2)
#apply works column wise
#where as applymap works for each element
# Out:
#    col1  col2
# a     4    16
# b    16    25
# c    36    36
# d    64    49

# %%
df4.sort_values('col3')
# Out:
#    col1  col2    col3
# c     6     6  hitesh
# b     4     5   krish
# d     8     7   navin
# a     2     4    sudh

# %%
df6=pd.DataFrame({'col1':["Over the last couple of decades, the technological advances in storage and processing power have enabled some innovative products based on machine learning, such as Netflix’s recommendation engine and self-driving cars.Machine learning is an important component of the growing field of data science. Through the use of statistical methods, algorithms are trained to make classifications or predictions, and to uncover key insights in data mining projects. These insights subsequently drive decision making within applications and businesses, ideally impacting key growth metrics. As big data continues to expand and grow, the market demand for data scientists will increase. They will be required to help identify the most relevant business questions and the data to answer them.Machine learning algorithms are typically created using frameworks that accelerate solution development, such as TensorFlow and PyTorch.","my name is viraj","i am jobless"],'col2':["1","2","3"]})
df6
# Out:
#                                                 col1 col2
# 0  Over the last couple of decades, the technolog...    1
# 1                                   my name is viraj    2
# 2                                       i am jobless    3

# %%
pd.set_option("display.max_colwidth",1000)
df6
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   col1  \
# ...

# %%
df6['char_len']=df6['col1'].apply(len)

# %%
df6
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   col1  \
# ...

# %%
a=" my name is viraj "
a.strip()
a.replace(" ", "")
# Out:
# 'mynameisviraj'

# %%
df6['word_count']=df6['col1'].apply(lambda x:len(x.split()))

# %%
df6
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   col1  \
# ...

# %%
df4
# Out:
#    col1  col2    col3
# a     2     4    sudh
# b     4     5   krish
# c     6     6  hitesh
# d     8     7   navin

# %%
df4['col1'].product()
# Out:
# 384

# %%
df4['col1'].rolling(window=1).mean()
# Out:
# a    2.0
# b    4.0
# c    6.0
# d    8.0
# Name: col1, dtype: float64

# %%
df4['col1'].rolling(window=2).mean()
# Out:
# a    NaN
# b    3.0
# c    5.0
# d    7.0
# Name: col1, dtype: float64

# %%
df4['col1'].rolling(window=3).mean()
# Out:
# a    NaN
# b    NaN
# c    4.0
# d    6.0
# Name: col1, dtype: float64

# %%
df4['col1'].rolling(window=2).sum()
# Out:
# a     NaN
# b     6.0
# c    10.0
# d    14.0
# Name: col1, dtype: float64

# %%
df4['col1'].cumsum()#cumulative sum
# Out:
# a     2
# b     6
# c    12
# d    20
# Name: col1, dtype: int64

# %%
date=pd.date_range(start='2023-03-06',end='2023-03-14')
date
df_date=pd.DataFrame({'DATE':date})
df_date
# Out:
#         DATE
# 0 2023-03-06
# 1 2023-03-07
# 2 2023-03-08
# 3 2023-03-09
# 4 2023-03-10
# 5 2023-03-11
# 6 2023-03-12
# 7 2023-03-13
# 8 2023-03-14

# %%
df_date.dtypes
# Out:
# DATE    datetime64[ns]
# dtype: object

# %%
df7=pd.DataFrame({'date':['2023-03-14','2023-03-13','2023-03-12']})

# %%
df7
df7.dtypes
# Out:
# date    object
# dtype: object

# %%
df7['updated_date']=pd.to_datetime(df7['date'])

# %%
df7
# Out:
#          date updated_date
# 0  2023-03-14   2023-03-14
# 1  2023-03-13   2023-03-13
# 2  2023-03-12   2023-03-12

# %%
df7.dtypes
# Out:
# date                    object
# updated_date    datetime64[ns]
# dtype: object

# %%
df_date
# Out:
#         DATE
# 0 2023-03-06
# 1 2023-03-07
# 2 2023-03-08
# 3 2023-03-09
# 4 2023-03-10
# 5 2023-03-11
# 6 2023-03-12
# 7 2023-03-13
# 8 2023-03-14

# %%
df_date['year']=df_date['DATE'].dt.year

# %%
df_date['month']=df_date['DATE'].dt.month

# %%
df_date['day']=df_date['DATE'].dt.day

# %%
df_date
# Out:
#         DATE  year  month  day
# 0 2023-03-06  2023      3    6
# 1 2023-03-07  2023      3    7
# 2 2023-03-08  2023      3    8
# 3 2023-03-09  2023      3    9
# 4 2023-03-10  2023      3   10
# 5 2023-03-11  2023      3   11
# 6 2023-03-12  2023      3   12
# 7 2023-03-13  2023      3   13
# 8 2023-03-14  2023      3   14

# %%
data=[1,2,3,1,1,1,2,3,4,4,2,2,1]
categorical_data=pd.Categorical(data)
categorical_data
# Out:
# [1, 2, 3, 1, 1, ..., 4, 4, 2, 2, 1]
# Length: 13
# Categories (4, int64): [1, 2, 3, 4]

# %%
categorical_data.value_counts()
# Out:
# 1    5
# 2    4
# 3    2
# 4    2
# dtype: int64

# %%
plot_df=pd.Series([1,2,3,4,4,5,5,6,8])

# %%
plot_df.plot()
# Out:
# <Axes: >

# %%
p1=pd.DataFrame({'x':[1,3,5,7,9],'y':[2,4,6,8,10]})

# %%
p1
# Out:
#    x   y
# 0  1   2
# 1  3   4
# 2  5   6
# 3  7   8
# 4  9  10

# %%
p1.plot.scatter(x='x',y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>
